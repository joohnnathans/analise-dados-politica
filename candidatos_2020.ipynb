# %% [markdown]
# <h1>Análise de politicos no Brasil <h1>
# <br>
#     Este projeto foi criado por <b> Jonathan César. </b>
#     Irei analisar alguns dados encontrados em
#     <a href='https://www.tse.jus.br/eleicoes/estatisticas/repositorio-de-dados-eleitorais-1'> aqui</a>.

# %%
##Aqui vamos importar as bibliotecas para a realização das analises 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
low_memory=False

# %%
##Carregando o DataSet na variavel DF
df = pd.read_csv('C:\\Users\\jcesar\OneDrive - Imagem Geosistemas e Comércio LTDA\\Desktop\\falculdade\\DataAnalysisConsulta_cand_2020\\consulta_cand_2020\\consulta_cand_2020_BRASIL.csv',
                 delimiter=';',
                 encoding='iso-8859-1',
                 usecols={"DT_GERACAO", "HH_GERACAO", "ANO_ELEICAO", "CD_TIPO_ELEICAO", "NM_TIPO_ELEICAO", "NR_TURNO", "CD_ELEICAO", "DS_ELEICAO", "DT_ELEICAO", "TP_ABRANGENCIA", "SG_UF", "SG_UE", "NM_UE", "CD_CARGO", "DS_CARGO", "SQ_CANDIDATO", "NR_CANDIDATO", "NM_CANDIDATO", "NM_URNA_CANDIDATO", "NM_SOCIAL_CANDIDATO", "NR_CPF_CANDIDATO", "NM_EMAIL", "CD_SITUACAO_CANDIDATURA", "DS_SITUACAO_CANDIDATURA", "CD_DETALHE_SITUACAO_CAND", "DS_DETALHE_SITUACAO_CAND", "TP_AGREMIACAO", "NR_PARTIDO", "SG_PARTIDO", "NM_PARTIDO", "SQ_COLIGACAO", "NM_COLIGACAO", "DS_COMPOSICAO_COLIGACAO", "CD_NACIONALIDADE", "DS_NACIONALIDADE", "SG_UF_NASCIMENTO", "CD_MUNICIPIO_NASCIMENTO", "NM_MUNICIPIO_NASCIMENTO", "DT_NASCIMENTO", "NR_IDADE_DATA_POSSE", "NR_TITULO_ELEITORAL_CANDIDATO", "CD_GENERO", "DS_GENERO", "CD_GRAU_INSTRUCAO", "DS_GRAU_INSTRUCAO", "CD_ESTADO_CIVIL", "DS_ESTADO_CIVIL", "CD_COR_RACA", "DS_COR_RACA", "CD_OCUPACAO", "DS_OCUPACAO", "VR_DESPESA_MAX_CAMPANHA", "CD_SIT_TOT_TURNO", "DS_SIT_TOT_TURNO", "ST_REELEICAO", "ST_DECLARAR_BENS", "NR_PROTOCOLO_CANDIDATURA", "NR_PROCESSO", "CD_SITUACAO_CANDIDATO_PLEITO", "DS_SITUACAO_CANDIDATO_PLEITO", "CD_SITUACAO_CANDIDATO_URNA", "DS_SITUACAO_CANDIDATO_URNA", "ST_CANDIDATO_INSERIDO_URNA"})

# %%
##Mostra o tamanho do csv (557634 linhas e 63 colunas)
df.shape
# Out:
# (557634, 63)

# %%
##Informações de cada coluna do csv
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557634 entries, 0 to 557633
# Data columns (total 63 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DT_GERACAO                     557634 non-null  object
#  1   HH_GERACAO                     557634 non-null  object
#  2   ANO_ELEICAO                    557634 non-null  int64
#  3   CD_TIPO_ELEICAO                557634 non-null  int64
#  4   NM_TIPO_ELEICAO                557634 non-null  object
#  5   NR_TURNO                       557634 non-null  int64
#  6   CD_ELEICAO                     557634 non-null  int64
#  7   DS_ELEICAO                     557634 non-null  object
#  8   DT_ELEICAO                     557634 non-null  object
#  9   TP_ABRANGENCIA                 557634 non-null  object
#  10  SG_UF                          557634 non-null  object
#  11  SG_UE                          557634 non-null  int64
# ...

# %%
#Visualização de 10 linhas das informações
df.sample(10)
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 485709  07/12/2020   11:17:31         2020                2
# 302724  07/12/2020   11:17:31         2020                2
# 112288  07/12/2020   11:17:31         2020                2
# 313427  07/12/2020   11:17:31         2020                2
# 228250  07/12/2020   11:17:31         2020                2
# 392392  07/12/2020   11:17:31         2020                2
# 496191  07/12/2020   11:17:31         2020                2
# 110845  07/12/2020   11:17:31         2020                2
# 513362  07/12/2020   11:17:31         2020                2
# 411850  07/12/2020   11:17:31         2020                2
#
#           NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO                DS_ELEICAO  \
# 485709  ELEIÇÃO ORDINÁRIA         1         426  Eleições Municipais 2020
# 302724  ELEIÇÃO ORDINÁRIA         1         426  Eleições Municipais 2020
# 112288  ELEIÇÃO ORDINÁRIA         1         426  Eleições Municipais 2020
# ...

# %%
df.groupby('SG_UF')['CD_DETALHE_SITUACAO_CAND'].max().sort_values().tail(10).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='SG_UF'>

# %%
##Contagem de candidatos ás eleições por Estado
df['SG_PARTIDO'].value_counts()
# Out:
# MDB              45165
# PSD              39750
# PP               38532
# DEM              33285
# PSDB             33272
# PT               31865
# REPUBLICANOS     28854
# PDT              28775
# PL               28474
# PSB              26978
# PTB              23831
# PSL              22200
# PODE             20721
# PSC              18131
# CIDADANIA        17538
# SOLIDARIEDADE    17152
# AVANTE           15284
# PATRIOTA         14410
# PV               12281
# PROS             11901
# PC do B          10727
# PRTB              8001
# PTC               6861
# PMN               5065
# DC                4881
# REDE              4873
# PSOL              4763
# PMB               2880
# NOVO               622
# PSTU               208
# PCO                143
# UP                 134
# PCB                 77
# Name: SG_PARTIDO, dtype: int64

# %%
##Contagem de canditos por partido mostando apenas 5 partidos
df['SG_PARTIDO'].value_counts().tail(5).plot()
# Out:
# <AxesSubplot:>

# %%
df.tail(14).plot(kind='bar', 
        x='SG_UF', y='NR_PARTIDO', color='GREEN')
# Out:
# <AxesSubplot:xlabel='SG_UF'>

# %%
##Os 10 partidos com mais candidatos e enfeitando o grafico com mais informações
df['SG_PARTIDO'].value_counts().head(10).plot(kind='bar', figsize=(11,5), grid = False, rot=0, color = 'green')
plt.title('Os 10 partidos com mais candidatos')
plt.xlabel('PARTIDOS')
plt.ylabel('Quantidade de Candidatos')
# Out:
# Text(0, 0.5, 'Quantidade de Candidatos')

# %%
##Mostrando por tabela a quantidade de partido usando a sigla do partido por estado
qtd_part = pd.crosstab(df['SG_PARTIDO'], df['SG_UF'])
qtd_part.head()
# Out:
# SG_UF        AC    AL   AM   AP    BA    CE   ES    GO   MA    MG  ...    PR  \
# SG_PARTIDO                                                         ...
# AVANTE       39   123  429   70  1281   306  267   424  627  4618  ...   480
# CIDADANIA    26   182  276   67   490   300  586  1199  435  2799  ...  1589
# DC           46    15  173    4   360   101  277   328  140   597  ...   415
# DEM         174   315  457  198  2822   485  604  2564  948  5345  ...  1849
# MDB         334  1248  858   91  1339  1102  502  1820  980  6122  ...  2912
#
# SG_UF         RJ    RN   RO   RR    RS    SC   SE    SP    TO
# SG_PARTIDO
# AVANTE       997   130  126   35   151   230  166  2440   149
# CIDADANIA   1036   249   42  146   555   486  486  3182   358
# DC           780    35   70   32     4   106   61   584    73
# DEM         1337   543  456   44  1233   713  331  6666   805
# MDB         1131  1233  553  147  5143  3518  429  6472  1063
#
# [5 rows x 26 columns]

# %%
##adicionando uma coluna de TOTAL para contar a quantidade de candidados por partido no Brasil inteiro
qtd_part['TOTAL'] =  crosstab_vg.sum(axis=1)
qtd_part.head()
# Out:
# SG_UF        AC    AL   AM   AP    BA    CE   ES    GO   MA    MG  ...    RJ  \
# SG_PARTIDO                                                         ...
# AVANTE       39   123  429   70  1281   306  267   424  627  4618  ...   997
# CIDADANIA    26   182  276   67   490   300  586  1199  435  2799  ...  1036
# DC           46    15  173    4   360   101  277   328  140   597  ...   780
# DEM         174   315  457  198  2822   485  604  2564  948  5345  ...  1337
# MDB         334  1248  858   91  1339  1102  502  1820  980  6122  ...  1131
#
# SG_UF         RN   RO   RR    RS    SC   SE    SP    TO  TOTAL
# SG_PARTIDO
# AVANTE       130  126   35   151   230  166  2440   149  30568
# CIDADANIA    249   42  146   555   486  486  3182   358  35076
# DC            35   70   32     4   106   61   584    73   9762
# DEM          543  456   44  1233   713  331  6666   805  66570
# MDB         1233  553  147  5143  3518  429  6472  1063  90330
#
# [5 rows x 27 columns]

# %%
##Aqui relacionamos com o Seaborn a quantidade de candidatos por partido nos Estados 
##O grafico mostra na ultima coluna a quantidade de candidatos TOTAL por partido no Brasil inteiro
##O grafico mostra na ultima  linha a quantidade de Candidatos TOTAL por Estado no Brasil Inteiro
qtd_total_part = crosstab_vg[crosstab_vg['TOTAL'] >1000].sort_values('TOTAL', ascending = False)
qtd_final = qtd_total_part.append(pd.DataFrame(qtd_total_part.sum(), columns=['TOTAL']).T, ignore_index=False)
sns.set(font_scale=1)
plt.figure(figsize=(18,9))
sns.heatmap(qtd_final, annot=True, vmax=qtd_final.loc[:'PT', :'MG'].values.max(), vmin=qtd_final.loc[:, :'MG'].values.min(), fmt='d')
# Out:
# <AxesSubplot:xlabel='SG_UF'>
